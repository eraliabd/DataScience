# %% [markdown]
# <a href="https://colab.research.google.com/github/eraliabd/DataScience/blob/main/%232_data_type.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Ma'lumotlar tahlili. (NumPy kutubxonasi)**

# %% [markdown]
# # **Ma'lumot turlari**

# %% [markdown]
# **NumPy kutubxonasini chaqirib olish.**

# %%
import numpy as np

# %% [markdown]
# ![image.png](data:image/png;base64,...)
